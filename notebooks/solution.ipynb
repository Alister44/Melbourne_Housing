# %% [markdown]
# <a href="https://colab.research.google.com/github/Alister44/Melbourne_Housing/blob/main/notebooks/solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import warnings

# %%
FILE_IN = 'https://raw.githubusercontent.com/Alister44/Melbourne_Housing/refs/heads/main/data/melb_data_dirty.csv'
df_original = pd.read_csv(FILE_IN)
df = df_original.copy()

# %% [markdown]
# Suburb	-  Район
# Address	- Адрес
# Rooms - Количество комнат
# Type - Тип
# Price - Цена
# Method - Способ продажи
# SellerG-Агентство
# Date - Дата(продажи)
# Distance - Расстояние
# Postcode - Почтовый индекс
# Bedroom2 - Спальни
# Bathroom - Ванные комнаты
# Car	Парковочные места
# Landsize	Площадь участка
# BuildingArea	Площадь строения
# YearBuilt	Год постройки
# CouncilArea	Муниципальный округ
# Lattitude	Широта
# Longtitude	Долгота
# Regionname	Регион
# Propertycount	Количество объектов недвижимости в данном районе

# %% [markdown]
# # описова статистика числових стовпців

# %%
display(df.describe().round(3))
# Out:
#            Rooms        Price   Distance   Postcode   Bedroom2   Bathroom  \
# count  13580.000    13580.000  13580.000  13580.000  13580.000  13580.000
# mean       2.938  1075684.079     10.138   3105.302      2.915      1.534
# std        0.956   639310.724      5.869     90.677      0.966      0.692
# min        1.000    85000.000      0.000   3000.000      0.000      0.000
# 25%        2.000   650000.000      6.100   3044.000      2.000      1.000
# 50%        3.000   903000.000      9.200   3084.000      3.000      1.000
# 75%        3.000  1330000.000     13.000   3148.000      3.000      2.000
# max       10.000  9000000.000     48.100   3977.000     20.000      8.000
#
#              Car    Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  \
# count  13518.000   13580.000      7130.000   8205.000  13580.000   13580.000
# mean       1.610     558.416       151.968   1964.684    -37.809     144.995
# ...

# %% [markdown]
# описова статистика всіх стопвпців

# %%
display(df.describe(include='all'))
# Out:
#            Suburb        Address         Rooms   Type         Price Method  \
# count       13580          13580  13580.000000  13580  1.358000e+04  13580
# unique        314          13378           NaN      3           NaN      5
# top     Reservoir  5 Margaret St           NaN      h           NaN      S
# freq          359              3           NaN   9449           NaN   9022
# mean          NaN            NaN      2.937997    NaN  1.075684e+06    NaN
# std           NaN            NaN      0.955748    NaN  6.393107e+05    NaN
# min           NaN            NaN      1.000000    NaN  8.500000e+04    NaN
# 25%           NaN            NaN      2.000000    NaN  6.500000e+05    NaN
# 50%           NaN            NaN      3.000000    NaN  9.030000e+05    NaN
# 75%           NaN            NaN      3.000000    NaN  1.330000e+06    NaN
# max           NaN            NaN     10.000000    NaN  9.000000e+06    NaN
#
# ...

# %% [markdown]
# Анализ пропущенных значений и типов

# %%
info = pd.DataFrame({
    "тип": df.dtypes.astype(str),
    'кількість пропусків': df.isnull().sum(),
    "пропусків_%": (df.isna().mean() * 100).round(1),
})
print(info.sort_values("пропусків_%", ascending=False))
# Out:
#                    тип  кількість пропусків  пропусків_%
# BuildingArea   float64                 6450         47.5
# YearBuilt      float64                 5375         39.6
# CouncilArea     object                 1369         10.1
# Car            float64                   62          0.5
# Suburb          object                    0          0.0
# Price          float64                    0          0.0
# Type            object                    0          0.0
# Rooms            int64                    0          0.0
# Address         object                    0          0.0
# Distance       float64                    0          0.0
# Method          object                    0          0.0
# Date            object                    0          0.0
# SellerG         object                    0          0.0
# Bathroom       float64                    0          0.0
# Bedroom2       float64                    0          0.0
# ...

# %% [markdown]
# Перевірка чи немає технічного стовпця-індексу, який потрапив у файл.Якщо є - прибераєм

# %%
clean = df.copy()
if 'Unnamed: 0' in clean.columns:
  clean = clean.drop(columns=['Unnamed: 0'])
  print('Column with index - deleted')
